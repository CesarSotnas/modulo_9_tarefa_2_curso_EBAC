# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('SINASC_RO_2019.csv')
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %%
sinasc_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27028 entries, 0 to 27027
# Data columns (total 69 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ORIGEM        27028 non-null  int64
#  1   CODESTAB      26913 non-null  float64
#  2   CODMUNNASC    27028 non-null  int64
#  3   LOCNASC       27028 non-null  int64
#  4   IDADEMAE      27028 non-null  int64
#  5   ESTCIVMAE     26711 non-null  float64
#  6   ESCMAE        26716 non-null  object
#  7   CODOCUPMAE    24121 non-null  float64
#  8   QTDFILVIVO    25455 non-null  float64
#  9   QTDFILMORT    24930 non-null  float64
#  10  CODMUNRES     27028 non-null  int64
#  11  GESTACAO      25796 non-null  object
#  12  GRAVIDEZ      26949 non-null  object
#  13  PARTO         26979 non-null  object
#  14  CONSULTAS     27028 non-null  int64
#  15  DTNASC        27028 non-null  object
#  16  HORANASC      27007 non-null  float64
#  17  SEXO          27024 non-null  object
# ...

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
round(sinasc_raw.groupby('munResNome')[['IDADEMAE', 'IDADEPAI']].mean())
# Out:
#                            IDADEMAE  IDADEPAI
# munResNome
# Alta Floresta D'Oeste          26.0      30.0
# Alto Alegre dos Parecis        25.0      29.0
# Alto Paraíso                   25.0      29.0
# Alvorada D'Oeste               26.0      31.0
# Ariquemes                      26.0      32.0
# Buritis                        26.0      31.0
# Cabixi                         26.0      34.0
# Cacaulândia                    26.0      36.0
# Cacoal                         27.0      31.0
# Campo Novo de Rondônia         25.0      30.0
# Candeias do Jamari             25.0      30.0
# Castanheiras                   27.0      30.0
# Cerejeiras                     27.0      32.0
# Chupinguaia                    25.0      30.0
# Colorado do Oeste              28.0      34.0
# Corumbiara                     25.0      32.0
# Costa Marques                  24.0      31.0
# Cujubim                        24.0      31.0
# Espigão D'Oeste                26.0      31.0
# ...

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
df_peso_medio = sinasc_raw[['ESCMAE', 'DTNASC', 'SEXO', 'PESO']]

# %%
df_peso_medio.head()
# Out:
#             ESCMAE      DTNASC       SEXO  PESO
# 0      8 a 11 anos  2019-02-19  Masculino  3685
# 1      8 a 11 anos  2019-02-21   Feminino  3055
# 2      8 a 11 anos  2019-02-25   Feminino  3460
# 3  12 anos ou mais  2019-03-20   Feminino  2982
# 4      8 a 11 anos  2019-03-23   Feminino  3310

# %%
df_peso_medio = df_peso_medio.groupby(['ESCMAE', 'DTNASC', 'SEXO']).mean()

# %%
round(df_peso_medio.sample(15))
# Out:
#                                         PESO
# ESCMAE          DTNASC     SEXO
# 4 a 7 anos      2019-12-17 Feminino   2500.0
# 12 anos ou mais 2019-06-02 Masculino  3822.0
#                 2019-08-20 Feminino   3110.0
#                 2019-05-19 Masculino  3850.0
# 8 a 11 anos     2019-03-24 Feminino   3243.0
#                 2019-07-11 Masculino  3406.0
#                 2019-01-05 Feminino   3408.0
# 4 a 7 anos      2019-09-05 Feminino   3064.0
# 12 anos ou mais 2019-01-12 Masculino  3243.0
# 4 a 7 anos      2019-10-11 Feminino   3190.0
# 12 anos ou mais 2019-01-20 Feminino   2724.0
#                 2019-10-14 Feminino   3174.0
# 4 a 7 anos      2019-08-22 Masculino  3528.0
# 8 a 11 anos     2019-01-16 Masculino  3472.0
# 1 a 3 anos      2019-06-19 Masculino  1925.0

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
df_min_bebe = sinasc_raw[['munResNome', 'DTNASC', 'QTDFILVIVO', 'IDADEMAE', 'IDADEPAI']]

# %%
df_min_bebe = df_min_bebe.loc[df_min_bebe['QTDFILVIVO'] > 0]

# %%
df_min_bebe = df_min_bebe.groupby(['QTDFILVIVO', 'munResNome']).agg({'IDADEMAE': ['min', 'max', 'mean'],
                                       'IDADEPAI': ['min', 'max', 'mean']})

# %% [markdown]
# * Como podemos ver, alguns municípios tiveram apenas 1 nascimento

# %%
round(df_min_bebe)
# Out:
#                                    IDADEMAE           IDADEPAI
#                                         min max  mean      min   max  mean
# QTDFILVIVO munResNome
# 1.0        Alta Floresta D'Oeste         17  46  27.0     18.0  50.0  31.0
#            Alto Alegre dos Parecis       16  38  26.0     19.0  46.0  31.0
#            Alto Paraíso                  16  41  26.0     24.0  29.0  26.0
#            Alvorada D'Oeste              16  37  26.0     18.0  52.0  32.0
#            Ariquemes                     14  44  27.0     29.0  46.0  38.0
# ...                                     ...  ..   ...      ...   ...   ...
# 11.0       Guajará-Mirim                 42  42  42.0      NaN   NaN   NaN
# 12.0       Espigão D'Oeste               40  40  40.0     43.0  43.0  43.0
#            Porto Velho                   42  44  43.0      NaN   NaN   NaN
# 14.0       Costa Marques                 39  39  39.0     43.0  43.0  43.0
# ...

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.

# %% [markdown]
# Exemplo:
# - Ah, descobri que a idade mediana das mulheres que deram a luz no ano de 2019 dos municipios x é maior que y.

# %%
sinasc_raw.dtypes
# Out:
# ORIGEM          int64
# CODESTAB      float64
# CODMUNNASC      int64
# LOCNASC         int64
# IDADEMAE        int64
#                ...
# munResUf       object
# munResLat     float64
# munResLon     float64
# munResAlt     float64
# munResArea    float64
# Length: 69, dtype: object

# %%
sinasc_raw.select_dtypes(exclude=['int64','float64'])
# Out:
#                 ESCMAE         GESTACAO GRAVIDEZ    PARTO      DTNASC  \
# 0          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-19
# 1          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-21
# 2          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-25
# 3      12 anos ou mais  37 a 41 semanas    Única  Cesáreo  2019-03-20
# 4          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-03-23
# ...                ...              ...      ...      ...         ...
# 27023  12 anos ou mais  32 a 36 semanas    Única  Cesáreo  2019-12-13
# 27024      8 a 11 anos  37 a 41 semanas    Única  Vaginal  2019-10-04
# 27025      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-08-02
# 27026      8 a 11 anos  32 a 36 semanas    Única  Vaginal  2019-12-23
# 27027      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-12-27
#
#             SEXO RACACOR  DTCADASTRO CODANOMAL VERSAOSIST   DTRECEBIM  \
# ...

# %%
df_mais_bebes_marco = sinasc_raw[['DTNASC', 'munResNome', 'QTDFILVIVO', 'IDADEPAI', 'IDADEMAE']]

# %%
df_mais_bebes_marco = df_mais_bebes_marco.loc[df_mais_bebes_marco['DTNASC'].str.startswith("2019-03")]

# %%
df_mais_bebes_marco
# Out:
#            DTNASC               munResNome  QTDFILVIVO  IDADEPAI  IDADEMAE
# 3      2019-03-20  Alto Alegre dos Parecis         0.0      24.0        30
# 4      2019-03-23    Alta Floresta D'Oeste         1.0      27.0        30
# 5      2019-03-27    Alta Floresta D'Oeste         2.0      40.0        33
# 9      2019-03-11    Alta Floresta D'Oeste         1.0      41.0        30
# 10     2019-03-11    Alta Floresta D'Oeste         1.0      28.0        31
# ...           ...                      ...         ...       ...       ...
# 13670  2019-03-21              Porto Velho         0.0       NaN        24
# 13671  2019-03-22              Porto Velho         2.0       NaN        24
# 13736  2019-03-07              Porto Velho         1.0      42.0        35
# 13748  2019-03-30                  Vilhena         2.0       NaN        36
# 13750  2019-03-09                Ji-Paraná         0.0      50.0        31
#
# [2456 rows x 5 columns]

# %% [markdown]
# * Município que nasceu mais bebês em Março foi Porto Velho

# %%
df_mais_bebes_marco['munResNome'].value_counts()
# Out:
# Porto Velho                  744
# Ji-Paraná                    188
# Vilhena                      148
# Ariquemes                    141
# Cacoal                       133
# Jaru                          80
# Guajará-Mirim                 75
# Rolim de Moura                69
# Ouro Preto do Oeste           67
# Pimenta Bueno                 62
# Buritis                       59
# Nova Mamoré                   53
# Machadinho D'Oeste            44
# Espigão D'Oeste               44
# São Miguel do Guaporé         41
# Candeias do Jamari            33
# São Francisco do Guaporé      31
# Alta Floresta D'Oeste         31
# Presidente Médici             29
# Costa Marques                 24
# Alto Paraíso                  22
# Alvorada D'Oeste              22
# Monte Negro                   20
# Nova Brasilândia D'Oeste      20
# Seringueiras                  19
# Colorado do Oeste             19
# Chupinguaia                   18
# Cujubim                       17
# ...

# %% [markdown]
# * quantidade de filhos vivos media, maxima, minima

# %%
df_municipio = df_mais_bebes_marco.loc[df_mais_bebes_marco['munResNome'] == 'Porto Velho']

# %%
df_municipio.head()
# Out:
#           DTNASC   munResNome  QTDFILVIVO  IDADEPAI  IDADEMAE
# 612   2019-03-09  Porto Velho         0.0       NaN        19
# 700   2019-03-28  Porto Velho         1.0       NaN        19
# 3232  2019-03-11  Porto Velho         0.0       NaN        34
# 3238  2019-03-13  Porto Velho         1.0       NaN        24
# 6818  2019-03-01  Porto Velho         2.0      41.0        38

# %%
print('Quantidade de filhos vivos em Porto Velho: ')
df_municipio['QTDFILVIVO'].value_counts().sum()
# Out:
# Quantidade de filhos vivos em Porto Velho:
# 627

# %%
print('Mínima, máxima e média: ')
round(df_municipio.groupby('munResNome').agg({'QTDFILVIVO':['min', 'max', 'mean']}))
# Out:
# Mínima, máxima e média:
#             QTDFILVIVO
#                    min  max mean
# munResNome
# Porto Velho        0.0  9.0  1.0
